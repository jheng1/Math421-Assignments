# %%
RHW1=read.csv("C:/Users/student/Downloads/R/titanic.csv")
RHW1$Survived = factor(RHW1$Survived)
RHW1$Pclass = factor(RHW1$Pclass)
library(ggplot2)


ggplot(data=RHW1)+geom_bar(mapping = aes(x=Survived, fill=Sex), position ="dodge")


ggplot(data=RHW1)+geom_bar(mapping = aes(x=Embarked, fill=Survived), position ="dodge")


ggplot(data=RHW1)+geom_point(mapping = aes(x=Age, y=Fare, color = Embarked))


ggplot(data=RHW1)+geom_bar(mapping = aes(x=Pclass, fill=Pclass)) + coord_polar()


ggplot(RHW1, aes(Fare))+geom_density()


ggplot(RHW1, aes(Age))+geom_density()


ggplot(data=RHW1)+geom_bar(mapping = aes(x=Age, fill=Survived), position ="dodge")
# Out:
# plot without title
# Warning message:
# "Removed 177 rows containing missing values (geom_point)."
# plot without title
# plot without title
# plot without title
# Warning message:
# "Removed 177 rows containing non-finite values (stat_density)."
# plot without title
# Warning message:
# "Removed 177 rows containing non-finite values (stat_count)."Warning message:
# "position_dodge requires non-overlapping x intervals"
# plot without title
# plot without title
